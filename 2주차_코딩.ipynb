# %%
print("2주차")
print(10+20)
# Out:
# 2주차
# 30

# %%
print("2주차 코딩")
# Out:
# 2주차 코딩

# %%
a=1, b=2
print(a+b)
# Out:
#   File "/tmp/ipykernel_3642/3548285259.py", line 1
#     a=1, b=2
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a, b = 1, 2
print(a+b)
# Out:
# 3

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
#두 자연수 10과 5가 주어진다.
#이때, A+B, A-B, A*B, A/B(몫), A%B(나머지)를 출력하는 프로그램을 작성하시오.

# %%
A, B = 10, 5
print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A%B)
# Out:
# 15
# 5
# 50
# 2.0
# 0

# %%
#가로12, 세로7인 직사각형의 넓이와 둘레를 구하시오.

# %%
width=12
height=7
area=width*height
perimeter=2*(width+height)
print("area=", area)
print("perimeter=", perimeter)
# Out:
# area= 84
# perimeter= 38

# %%
#국어 88, 영어 92, 수학 75점인 학생의 과목 평균을 구하시오.

# %%
Korean=88
English=92
Math=75
average=(Korean+English+Math)/3
print("average=", average)
# Out:
# average= 85.0
